# %% [markdown]
# Mounting Azure Data Lake Storage using client credentials

# %%
# %scala

val configs = Map(
  "dfs.adls.oauth2.access.token.provider.type" -> "ClientCredential",
 "dfs.adls.oauth2.client.id" -> "1ce2a76c-f72f-4f9f-a24f-00521b10a3c8",  //App ID
  "dfs.adls.oauth2.credential" -> "qK68Q~QGBipyjwZfUyQXbpRQMx8uMhzGLl4mcbK1", // Secret value
  "dfs.adls.oauth2.refresh.url" -> "https://login.micorosoftonline.com/345e1e02-c9fe-42fc-a67d-591c3b77642e/oauth2/token"  //Directory ID
)

dbutils.fs.mount(
    source = "adl://meyyaadlsgen2.dfs.core.windows.net/",
    mountPoint = "/mnt/datalake",
    extraConfigs = configs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/datalake
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# ...

# %% [markdown]
# Mounting storage accounts using Access key

# %%
# %scala
val configs =Map(
  "fs.azure.account.key.meyyaadlsgen2.blob.core.windows.net" -> "eHuG3axo87mIX8cj8cEQkTIRrZgZdQC7oOcyGC7ZJwoS5Q//TlggSLMYcVAIlf23q9/vlALvQ7Ze+AStX1m9EA==" // access key
)

dbutils.fs.mount(
  source = "wasbs://rawzone@meyyaadlsgen2.blob.core.windows.net/",
  mountPoint = "/mnt/storage", extraConfigs = configs
  )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">configs: scala.collection.immutable.Map[String,String] = Map(fs.azure.account.key.meyyaadlsgen2.blob.core.windows.net -&gt; eHuG3axo87mIX8cj8cEQkTIRrZgZdQC7oOcyGC7ZJwoS5Q//TlggSLMYcVAIlf23q9/vlALvQ7Ze+AStX1m9EA==)
# res5: Boolean = true
# </div>

# %% [markdown]
# Assign parquet file data to a spark dataframe

# %%
# %scala
var taxiDF = spark
.read
.parquet("/mnt/storage/taxirides/yellow_tripdata_2022-01.parquet")

display(taxiDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs mounts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
import pandas as pd ##import pandas, its used for data analysis
moviecsv = pd.read_csv('https://raw.githubusercontent.com/meyya22/AI-Docs/master/movies.csv')
print("Displaying my First Databricks Table")

display(moviecsv)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Displaying my First Databricks Table
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
len(moviecsv)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 45843</div>
